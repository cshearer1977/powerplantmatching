# %%
import powerplantmatching as pm
pm.powerplants(from_url=True)
# Out:
# INFO:powerplantmatching.collection:Retrieving data from https://raw.githubusercontent.com/FRESNA/powerplantmatching/v0.5.15/powerplants.csv
# INFO:powerplantmatching.collection:Store data at /Users/christines/.local/share/powerplantmatching/data/out/default/matched_data_red.csv
# Matched Data                  Name   Fueltype     Technology    Set  \
# id
# 0                         Borssele  Hard Coal  Steam Turbine     PP
# 1                      Ottmarsheim      Hydro   Run-Of-River     PP
# 2                    Pied De Borne      Hydro      Reservoir  Store
# 3                           Pouget      Hydro      Reservoir  Store
# 4                        Pragneres      Hydro      Reservoir  Store
# ...                            ...        ...            ...    ...
# 7149                         Zalau    Lignite            NaN     PP
# 7150                         Zavod    Lignite            NaN     PP
# 7151                          Zlin    Lignite            NaN     PP
# ...

# %%
pm.powerplants(reduced=False)
# Out:
# INFO:powerplantmatching.collection:Create combined dataset for BEYONDCOAL, ENTSOE, GEM, GEO, GPD, JRC, OPSD, WIKIPEDIA
# WARNING:powerplantmatching.collection:Forcing update since the cache file is missing
# INFO:powerplantmatching.core:Retrieving data from https://beyond-coal.eu/wp-content/uploads/2021/07/2021-04-20_Europe_Beyond_Coal-European_Coal_Database_hc5n.xlsx
# INFO:powerplantmatching.data:No entsoe_token in config.yaml given, falling back to stored version.
# INFO:powerplantmatching.core:Retrieving data from https://raw.githubusercontent.com/pypsa-meets-earth/ppm-data-backup/main/entsoe_powerplants.csv
# INFO:powerplantmatching.cleaning:Aggregating blocks in data source 'ENTSOE'.
# INFO:powerplantmatching.cleaning:Aggregating blocks in data source 'GEM'.
# INFO:powerplantmatching.cleaning:Aggregating blocks in data source 'GEO'.
# INFO:powerplantmatching.cleaning:Aggregating blocks in data source 'GPD'.
# ...

# %%
pm.powerplants
# Out:
# <function powerplantmatching.collection.powerplants(config=None, config_update=None, update=False, from_url=False, extend_by_vres=False, extendby_kwargs={}, extend_by_kwargs={'query': "(Country not in ['Switzerland', 'Ireland', 'Albania', 'Greece', 'Czech Republic', 'Bulgaria', 'United Kingdom', 'Italy', 'Serbia'] and not (Country == 'Spain' and Fueltype == 'Hydro')) or (Fueltype == 'Geothermal')"}, fill_geopositions=True, filter_missing_geopositions=True, **collection_kwargs)>

# %%
pm.powerplants(reduced=True)
# Out:
# Matched Data                  Name   Fueltype     Technology    Set  \
# id
# 0                         Borssele  Hard Coal  Steam Turbine     PP
# 1                      Ottmarsheim      Hydro   Run-Of-River     PP
# 2                    Pied De Borne      Hydro      Reservoir  Store
# 3                           Pouget      Hydro      Reservoir  Store
# 4                        Pragneres      Hydro      Reservoir  Store
# ...                            ...        ...            ...    ...
# 7149                         Zalau    Lignite            NaN     PP
# 7150                         Zavod    Lignite            NaN     PP
# 7151                          Zlin    Lignite            NaN     PP
# 7152          Zofiowka Moszczenica  Hard Coal            NaN     PP
# 7153                     Zvolenska    Lignite            NaN     PP
#
# Matched Data         Country    Capacity  Efficiency  DateIn  DateRetrofit  \
# id
# ...
